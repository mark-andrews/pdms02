# %%
import statsmodels
import statsmodels.formula.api as smf

import pandas as pd

import numpy as np

# %%
weight_df = pd.read_csv('weight.csv')

# %%
m = smf.ols('weight ~ height', data = weight_df)

# %%
results = m.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 weight   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     4688.
# Date:                Thu, 07 May 2020   Prob (F-statistic):               0.00
# Time:                        11:10:36   Log-Likelihood:                -23563.
# No. Observations:                6068   AIC:                         4.713e+04
# Df Residuals:                    6066   BIC:                         4.714e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -117.1280      2.879    -40.688      0.000    -122.771    -111.485
# ...

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 weight   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     4688.
# Date:                Thu, 07 May 2020   Prob (F-statistic):               0.00
# Time:                        11:15:09   Log-Likelihood:                -23563.
# No. Observations:                6068   AIC:                         4.713e+04
# Df Residuals:                    6066   BIC:                         4.714e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -117.1280      2.879    -40.688      0.000    -122.771    -111.485
# ...

# %%
affairs_df = pd.read_csv('affairs.csv')

# %%
affairs_df = affairs_df.assign(cheater = 1*(affairs_df.affairs > 0))

# %%
affairs_df
# Out:
#      affairs  gender   age  yearsmarried children  religiousness  education  \
# 0          0    male  37.0         10.00       no              3         18
# 1          0  female  27.0          4.00       no              4         14
# 2          0  female  32.0         15.00      yes              1         12
# 3          0    male  57.0         15.00      yes              5         18
# 4          0    male  22.0          0.75       no              2         17
# ..       ...     ...   ...           ...      ...            ...        ...
# 596        1    male  22.0          1.50      yes              1         12
# 597        7  female  32.0         10.00      yes              2         18
# 598        2    male  32.0         10.00      yes              2         17
# 599        2    male  22.0          7.00      yes              3         18
# 600        1  female  32.0         15.00      yes              3         14
#
#      occupation  rating  cheater
# ...

# %%
smf.logit('cheater ~ age + yearsmarried + gender', data = affairs_df).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.546050
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                cheater   No. Observations:                  601
# Model:                          Logit   Df Residuals:                      597
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 07 May 2020   Pseudo R-squ.:                 0.02817
# Time:                        11:20:29   Log-Likelihood:                -328.18
# converged:                       True   LL-Null:                       -337.69
# Covariance Type:            nonrobust   LLR p-value:                 0.0002702
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
m_logit.fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.546050
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                cheater   No. Observations:                  601
# Model:                          Logit   Df Residuals:                      597
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 07 May 2020   Pseudo R-squ.:                 0.02817
# Time:                        11:19:50   Log-Likelihood:                -328.18
# converged:                       True   LL-Null:                       -337.69
# Covariance Type:            nonrobust   LLR p-value:                 0.0002702
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
